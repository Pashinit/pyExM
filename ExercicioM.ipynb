# %%
import modo_ex

m = 0

while m != '7':
    print('''
            --- Menu ---
    1: Adicionar elemento à Lista
    2: Adicionar elemento ao Set
    3: Adicionar elemento ao Tuple
    4: Adicionar elemento ao Dicionário
    5: Imprimir
    6: Eliminar
    7: Sair
    ''')

    m = str(input("Escolha a sua opção: "))

    if m == '1':
        modo_ex.add_list()
    elif m == '2':
        modo_ex.add_set()
    elif m == '3':
        modo_ex.add_tuple()
    elif m == '4':
        modo_ex.add_dic()
    elif m == '5':
        modo_ex.printAll()
    elif m == '6':
        modo_ex.delet()
    elif m == '7':
        break
    else:
        print("ERRO!Introduza alguma opção!")
# Out:
#             --- Menu ---
#     1: Adicionar elemento à Lista
#     2: Adicionar elemento ao Set
#     3: Adicionar elemento ao Tuple
#     4: Adicionar elemento ao Dicionário
#     5: Imprimir
#     6: Eliminar
#     7: Sair
#
# Escolha a sua opção: 6
#
#         --- DELETE ---
#         1: EliminarListas
#         2: Eliminar Set's
#         3: Eliminar Tuples
#         4: Eliminar Dicinários
#         5: MASTER DELETE
#         6: Voltar
#
# Escolha a sua opção: 1
#
#         --- DEL LIST ---
#         1: Lista Vazia
#         2: Lista Vazia Individual
#         3: Lista Cheia
#         4: Lista Cheia Individual
#         5: Voltar
#
# Escolha a sua opção: fg
# ERRO!Inroduza alguma opção!
#
#         --- DEL LIST ---
#         1: Lista Vazia
#         2: Lista Vazia Individual
#         3: Lista Cheia
#         4: Lista Cheia Individual
#         5: Voltar
#
# Escolha a sua opção:
# ERRO!Inroduza alguma opção!
#
#         --- DEL LIST ---
#         1: Lista Vazia
#         2: Lista Vazia Individual
#         3: Lista Cheia
#         4: Lista Cheia Individual
#         5: Voltar
#
# Escolha a sua opção: 1
# ERRO! Lista Vazia
#
#         --- DELETE ---
#         1: EliminarListas
#         2: Eliminar Set's
#         3: Eliminar Tuples
#         4: Eliminar Dicinários
#         5: MASTER DELETE
#         6: Voltar
#
# Escolha a sua opção: 1
#
#         --- DEL LIST ---
#         1: Lista Vazia
#         2: Lista Vazia Individual
#         3: Lista Cheia
#         4: Lista Cheia Individual
#         5: Voltar
#
# Escolha a sua opção: 3
# []
# ERRO!Inroduza alguma opção!
#
#         --- DEL LIST ---
#         1: Lista Vazia
#         2: Lista Vazia Individual
#         3: Lista Cheia
#         4: Lista Cheia Individual
#         5: Voltar
